# %%
from datasets import load_dataset, Image

dataset_train = load_dataset(
    "imagefolder", data_dir="./images",split="train",drop_labels=False)

dataset_train
# Out:
# Resolving data files:   0%|          | 0/15042 [00:00<?, ?it/s]
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 15042
# })

# %%
# check how many labels/number of classes
num_classes = len(set(dataset_train['label']))
labels = dataset_train.features['label']
num_classes, labels
# Out:
# (1, ClassLabel(names=['chair'], id=None))

# %%
dataset_train[0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=70x62>,
#  'label': 0}

# %%
dataset_train[400]['image']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=518x669>
